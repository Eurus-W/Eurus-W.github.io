# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# %pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already satisfied: getorg in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: retrying in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from getorg) (1.3.4)
# Requirement already satisfied: geopy in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from getorg) (2.6.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from geopy->getorg) (2.0)
# Requirement already satisfied: Deprecated in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pygithub->getorg) (1.2.18)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pygithub->getorg) (1.26.19)
# Requirement already satisfied: pynacl>=1.4.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pygithub->getorg) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pygithub->getorg) (4.12.2)
# Requirement already satisfied: requests>=2.14.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: six>=1.7.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from retrying->getorg) (1.16.0)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (39.0.1)
# Requirement already satisfied: cffi>=1.4.1 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.15.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from requests>=2.14.0->pygithub->getorg) (2.0.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from Deprecated->pygithub->getorg) (1.17.2)
# Requirement already satisfied: pycparser in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)

# %%
# %pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 503.3 kB/s eta 0:00:00a 0:00:01
# Collecting widgetsnbextension~=4.0.12
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 4.7 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: traitlets>=4.3.1 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipywidgets) (5.7.1)
# Collecting jupyterlab-widgets~=3.0.12
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.1.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipywidgets) (8.10.0)
# Collecting comm>=0.1.3
#   Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: appnope in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.2)
# Requirement already satisfied: stack-data in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: jedi>=0.16 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: backcall in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: pickleshare in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pure-eval in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: six in /Users/stephenwang/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, comm, ipywidgets
#   Attempting uninstall: comm
#     Found existing installation: comm 0.1.2
#     Uninstalling comm-0.1.2:
#       Successfully uninstalled comm-0.1.2
# Successfully installed comm-0.2.2 ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
g = glob.glob("_talks/*.md")

# %%
geocoder = Nominatim(user_agent="stephen")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Los Angeles, CA
#  California, United States
# London, UK
#  London, Greater London, England, United Kingdom
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/connectionpool.py:712, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711 if is_new_proxy_conn and http_tunnel_required:
# --> 712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/connectionpool.py:1014, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1012     conn.tls_in_tls_required = True
# -> 1014 conn.connect()
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#
# TimeoutError: _ssl.c:980: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/connectionpool.py:829, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826     log.warning(
#     827         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     828     )
# --> 829     return self.urlopen(
#     830         method,
#     831         url,
#     832         body,
#     833         headers,
#     834         retries,
#     835         redirect,
#     836         assert_same_host,
#     837         timeout=timeout,
#     838         pool_timeout=pool_timeout,
#     839         release_conn=release_conn,
#     840         chunked=chunked,
#     841         body_pos=body_pos,
#     842         **response_kw
#     843     )
#     845 # Handle redirect?
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/connectionpool.py:829, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826     log.warning(
#     827         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     828     )
# --> 829     return self.urlopen(
#     830         method,
#     831         url,
#     832         body,
#     833         headers,
#     834         retries,
#     835         redirect,
#     836         assert_same_host,
#     837         timeout=timeout,
#     838         pool_timeout=pool_timeout,
#     839         release_conn=release_conn,
#     840         chunked=chunked,
#     841         body_pos=body_pos,
#     842         **response_kw
#     843     )
#     845 # Handle redirect?
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/connectionpool.py:801, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     799     e = ProtocolError("Connection aborted.", e)
# --> 801 retries = retries.increment(
#     802     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     803 )
#     804 retries.sleep()
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/urllib3/util/retry.py:594, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     593 if new_retry.is_exhausted():
# --> 594     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     596 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Berkeley+CA%2C+USA&format=json&limit=1 (Caused by ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:980: The handshake operation timed out')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/geopy/adapters.py:482, in RequestsAdapter._request(self, url, timeout, headers)
#     481 try:
# --> 482     resp = self.session.get(url, timeout=timeout, headers=headers)
#     483 except Exception as error:
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/requests/adapters.py:694, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     693 if isinstance(e.reason, _ProxyError):
# --> 694     raise ProxyError(e, request=request)
#     696 if isinstance(e.reason, _SSLError):
#     697     # This branch is for urllib3 v1.22 and later.
#
# ProxyError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Berkeley+CA%2C+USA&format=json&limit=1 (Caused by ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:980: The handshake operation timed out')))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# Cell In[12], line 11
#       7     loc_end = lines_trim.find('"')
#       8     location = lines_trim[:loc_end]
# ---> 11 location_dict[location] = geocoder.geocode(location)
#      12 print(location, "\n", location_dict[location])
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/geopy/geocoders/nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/geopy/geocoders/base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/geopy/adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#     474         return resp.json()
#
# File ~/opt/anaconda3/envs/torchcpu/lib/python3.10/site-packages/geopy/adapters.py:494, in RequestsAdapter._request(self, url, timeout, headers)
#     492         raise GeocoderServiceError(message)
#     493     else:
# --> 494         raise GeocoderUnavailable(message)
#     495 elif isinstance(error, requests.Timeout):
#     496     raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Berkeley+CA%2C+USA&format=json&limit=1 (Caused by ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:980: The handshake operation timed out')))

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
